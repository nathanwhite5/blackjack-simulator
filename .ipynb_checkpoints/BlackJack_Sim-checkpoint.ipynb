# %% [markdown]
# blackjack simulator
#
# 416 cards, sample without replacement.
# keyboard prompt.
# usually shuffle at half, get to run through full 416 before half shuffle.

# %% [markdown]
# we need a deck, how would we populate/create a deck. first thought list, Jefe suggest dictionary if able to have repeats.

# %% [markdown]
# first without player input. we need to first get the simulator up and running, ~~10million hands. before novelty.

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import random as rd
import numpy as np

# %% [markdown]
# # Deck Builder

# %%
suits_list = [
    'Spades'
    ,'Hearts'
    ,'Clubs'
    ,'Diamonds'
]

rank_list = [
    'Ace'
    ,'King'
    ,'Queen'
    ,'Jack'
    ,'Ten'
    ,'Nine'
    ,'Eight'
    ,'Seven'
    ,'Six'
    ,'Five'
    ,'Four'
    ,'Three'
    ,'Two'
]

single_deck = []

for suit in suits_list:
    for rank in rank_list:
        single_deck.append(f'{rank} {suit}')

# %%
len(single_deck)
# Out:
# 52

# %%
type(single_deck)
# Out:
# list

# %%
print(single_deck)
# Out:
# ['Ace Spades', 'King Spades', 'Queen Spades', 'Jack Spades', 'Ten Spades', 'Nine Spades', 'Eight Spades', 'Seven Spades', 'Six Spades', 'Five Spades', 'Four Spades', 'Three Spades', 'Two Spades', 'Ace Hearts', 'King Hearts', 'Queen Hearts', 'Jack Hearts', 'Ten Hearts', 'Nine Hearts', 'Eight Hearts', 'Seven Hearts', 'Six Hearts', 'Five Hearts', 'Four Hearts', 'Three Hearts', 'Two Hearts', 'Ace Clubs', 'King Clubs', 'Queen Clubs', 'Jack Clubs', 'Ten Clubs', 'Nine Clubs', 'Eight Clubs', 'Seven Clubs', 'Six Clubs', 'Five Clubs', 'Four Clubs', 'Three Clubs', 'Two Clubs', 'Ace Diamonds', 'King Diamonds', 'Queen Diamonds', 'Jack Diamonds', 'Ten Diamonds', 'Nine Diamonds', 'Eight Diamonds', 'Seven Diamonds', 'Six Diamonds', 'Five Diamonds', 'Four Diamonds', 'Three Diamonds', 'Two Diamonds']

# %% [markdown]
# # Value Assigner (for later)

# %%
##note, not sure how to handle ace 11/1 switcher
## choosing Ace = 11 for now
rank_value_dict = {'Ace': 11
                   ,'King':10
                   ,'Queen':10
                   ,'Jack':10
                   ,'Ten':10
                   ,'Nine':9
                   ,'Eight':8
                   ,'Seven':7
                   ,'Six':6
                   ,'Five':5
                   ,'Four':4
                   ,'Three':3
                   ,'Two':2
}

# %% [markdown]
# # Live Deck Shuffler

# %%
live_deck = rd.sample(single_deck, len(single_deck))

print(live_deck)
len(live_deck)
# Out:
# ['Eight Hearts', 'Two Hearts', 'Jack Clubs', 'Jack Spades', 'Five Clubs', 'Queen Hearts', 'Ten Spades', 'Nine Clubs', 'King Diamonds', 'Seven Spades', 'Six Diamonds', 'Eight Spades', 'Ace Spades', 'Four Hearts', 'Seven Diamonds', 'Eight Clubs', 'King Hearts', 'Five Diamonds', 'Jack Diamonds', 'Six Clubs', 'Seven Clubs', 'Two Diamonds', 'Ten Diamonds', 'Queen Clubs', 'Two Clubs', 'King Spades', 'Eight Diamonds', 'Nine Spades', 'Four Spades', 'Ace Hearts', 'Three Hearts', 'Queen Diamonds', 'Seven Hearts', 'Two Spades', 'Five Spades', 'Six Hearts', 'Three Diamonds', 'Five Hearts', 'Four Diamonds', 'Four Clubs', 'Jack Hearts', 'Three Spades', 'Queen Spades', 'Ten Clubs', 'Three Clubs', 'Nine Hearts', 'Ace Clubs', 'Ten Hearts', 'Ace Diamonds', 'Nine Diamonds', 'Six Spades', 'King Clubs']
# 52

# %%
# confirming randomness 
card_counts_dict = {}

for i in live_deck:
    if i not in card_counts_dict:
        card_counts_dict[i] = 1
    else:
        card_counts_dict[i] = card_counts_dict[i] + 1

card_counts_dict
# Out:
# {'Eight Hearts': 1,
#  'Two Hearts': 1,
#  'Jack Clubs': 1,
#  'Jack Spades': 1,
#  'Five Clubs': 1,
#  'Queen Hearts': 1,
#  'Ten Spades': 1,
#  'Nine Clubs': 1,
#  'King Diamonds': 1,
#  'Seven Spades': 1,
#  'Six Diamonds': 1,
#  'Eight Spades': 1,
#  'Ace Spades': 1,
#  'Four Hearts': 1,
#  'Seven Diamonds': 1,
#  'Eight Clubs': 1,
#  'King Hearts': 1,
#  'Five Diamonds': 1,
#  'Jack Diamonds': 1,
#  'Six Clubs': 1,
#  'Seven Clubs': 1,
#  'Two Diamonds': 1,
#  'Ten Diamonds': 1,
#  'Queen Clubs': 1,
#  'Two Clubs': 1,
#  'King Spades': 1,
#  'Eight Diamonds': 1,
#  'Nine Spades': 1,
#  'Four Spades': 1,
#  'Ace Hearts': 1,
#  'Three Hearts': 1,
#  'Queen Diamonds': 1,
#  'Seven Hearts': 1,
#  'Two Spades': 1,
#  'Five Spades': 1,
#  'Six Hearts': 1,
#  'Three Diamonds': 1,
#  'Five Hearts': 1,
#  'Four Diamonds': 1,
#  'Four Clubs': 1,
#  'Jack Hearts': 1,
#  'Three Spades': 1,
#  'Queen Spades': 1,
#  'Ten Clubs': 1,
#  'Three Clubs': 1,
#  'Nine Hearts': 1,
#  'Ace Clubs': 1,
#  'Ten Hearts': 1,
#  'Ace Diamonds': 1,
#  'Nine Diamonds': 1,
#  'Six Spades': 1,
#  'King Clubs': 1}

# %% [markdown]
# # Hand Dealer (Line By Line)

# %% [markdown]
# # Player Input

# %% [markdown]
# ## 03.28.26 edits

# %% [markdown]
# 'copy' on raw/unshuffled deck, not the .rd
# 'shuffle deck' moved out of play_hand func

# %%
## shuffling deck
live_deck = rd.sample(single_deck, len(single_deck)) ## note, copy will be on unshuffled deck.

# %%
## playing single hand
def play_hand():

    max_total = 21
    
    ##player hand
    player_hand = []
    player_hand_total = 0

    ##dealer hand
    dealer_hand = []
    dealer_hand_total = 0

    ## INITIAL DEAL
    #first player card draw
    player_hand.append(live_deck.pop())

    #first dealer card draw
    dealer_hand.append(live_deck.pop())

    #second player card draw
    player_hand.append(live_deck.pop())

    #second dealer card draw
    dealer_hand.append(live_deck.pop())

    AcePlay_Player = False
    #player card value assign
    for card in player_hand:
        rank,suit = card.split()
        player_hand_total = player_hand_total + rank_value_dict[rank]
        if rank == 'Ace':
            AcePlay_Player = True


    AcePlay_Dealer = False
    #dealer card value assign
    for card in dealer_hand:
        rank,suit = card.split()
        dealer_hand_total = dealer_hand_total + rank_value_dict[rank]
        if rank == 'Ace':
            AcePlay_Dealer = True

    print(f"Player's Current Hand: {player_hand}. Hand Total: {player_hand_total}")
    print(f"Dealer Showing: {dealer_hand[0]}. Dealer Showing Total: {rank_value_dict[dealer_hand[0]}")
    print(f"Number of Cards Remaining in Deck: {len(live_deck_copy)}")

    if player_hand_total == 21:
        return f'Blackjack!'

    if player_hand_total == 21:
        return f'Blackjack!'
            
    ##user input
    # '1' and '0' are strings
    user_data = '1'
    drop_10_toggle_player = False
    
    while user_data != '0':
        
        print(f"You have {player_hand} for a total of {player_hand_total}. Dealer is showing {dealer_hand[0]} for a total of {rank_value_dict[dealer_hand[0].split()[0]]}. Press '1' to HIT, Press '0' to STAND")
        user_data = input()
        
        if user_data == '1':

            print(f'Player HITS')
            #draw card function, embed in deal hand function inside 'hit'
            #ensure player_hand_total also updates
            #ensure total cards left updates
            new_card = live_deck.pop()
            
            player_hand.append(new_card)
            
            rank,suit = new_card.split()
            
            player_hand_total = player_hand_total + rank_value_dict[rank]
            
            if rank == 'Ace':
                AcePlay_Player = True
        
            if player_hand_total > 21:
                if drop_10_player != True: #include single-use drop_10 trigger
                    if AcePlay_Player == False:
                        return f'Player BUSTS'
                else:
                    player_hand_total = player_hand total - 10
                    drop_10_player = True
            ###
        elif user_data == '0':
            print(f'Player STANDS')
            ###
        else:
            print(f"INCORRECT ENTRY")

    drop_10_toggle_dealer = False
    
    if dealer_hand_total <= 17 and AcePlay_Dealer == False:#note, hit on soft 17
        
        new_card = dealer_hand.append(live_deck_copy.pop())
        
        dealer_hand.append(new_card)

        rank,suit = new_card.split()
        
        dealer_hand_total = dealer_hand_total + rank_value_dict[rank]
        
        if rank == 'Ace':
            AcePlay_Dealer = True
        
        if dealer_hand_total == 17 and AcePlay_Dealer == True: ## **and toggle == false: 
            #subtract 10
            #include drop10 dealer toggle (note, unique toggle for dealer and player)
        
    if dealer_hand_total > 21:
        if AcePlayer == False:
            return f'Dealer BUSTS'
# Out:
#   Cell In[38], line 45
#     print(f"Dealer Showing: {dealer_hand[0]}. Dealer Showing Total: {rank_value_dict[dealer_hand[0]}")
#                                                                                                    ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %% [markdown]
# ## testing environ.

# %%
live_deck_tester = rd.sample(single_deck, len(single_deck))

# %%
len(live_deck_tester)
print(live_deck_tester)
# Out:
# ['Six Hearts', 'Four Diamonds', 'Ace Hearts', 'Two Hearts', 'Jack Clubs', 'Eight Hearts', 'Six Clubs', 'Ten Spades', 'Ten Clubs', 'Queen Hearts', 'Six Diamonds', 'Eight Spades', 'Two Diamonds', 'King Diamonds', 'Three Diamonds', 'Three Clubs', 'Eight Diamonds', 'Nine Hearts', 'Jack Diamonds', 'Nine Clubs', 'Three Spades', 'Seven Spades', 'King Clubs', 'Seven Hearts', 'Nine Diamonds', 'Two Spades', 'Five Clubs', 'Four Clubs', 'Ace Clubs', 'Six Spades', 'Ace Spades', 'Jack Spades', 'Ace Diamonds', 'Ten Diamonds', 'Five Diamonds', 'Eight Clubs', 'Jack Hearts', 'Queen Diamonds', 'Nine Spades', 'Queen Spades', 'Four Hearts', 'King Spades', 'Two Clubs', 'King Hearts', 'Ten Hearts', 'Seven Clubs', 'Queen Clubs', 'Five Hearts', 'Three Hearts', 'Four Spades', 'Five Spades', 'Seven Diamonds']

# %%
live_deck_tester_copy = live_deck_tester.copy()
max_total = 21

##player hand
player_hand = []
player_hand_total = 0

##dealer hand
dealer_hand = []
dealer_hand_total = 0

## INITIAL DEAL
#first player card draw
player_hand.append(live_deck_tester_copy.pop())

#first dealer card draw
dealer_hand.append(live_deck_tester_copy.pop())

#second player card draw
player_hand.append(live_deck_tester_copy.pop())

#second dealer card draw
dealer_hand.append(live_deck_tester_copy.pop())

AcePlay_Player = False
drop_10_toggle_player = False
#player card value assign
for card in player_hand:
    rank,suit = card.split()
    player_hand_total = player_hand_total + rank_value_dict[rank]
    if rank == 'Ace':
        AcePlay_Player = True


AcePlay_Dealer = False
drop10_toggle_dealer = False
#dealer card value assign
for card in dealer_hand:
    rank,suit = card.split()
    dealer_hand_total = dealer_hand_total + rank_value_dict[rank]
    if rank == 'Ace':
        AcePlay_Dealer = True

# %%
print(f"Player's Current Hand: {player_hand}. Hand Total: {player_hand_total}")
print(f"Dealer's Hand: {dealer_hand}. Hand Total: {dealer_hand_total}")
print(f"Number of Cards Remaining in Deck: {len(live_deck_tester_copy)}")
# Out:
# Player's Current Hand: ['Seven Diamonds', 'Four Spades']. Hand Total: 11
# Dealer's Hand: ['Five Spades', 'Three Hearts']. Hand Total: 8
# Number of Cards Remaining in Deck: 48

# %%
print(AcePlay_Player)
# Out:
# False

# %%
aceHand = 'Ace Spades'
player_hand[1] = aceHand
AcePlay_Player = True
player_hand_total = 18

# %%
print(player_hand)
print(player_hand_total)
# Out:
# ['Seven Diamonds', 'Ace Spades']
# 18

# %%
print(AcePlay_Player)
# Out:
# True

# %%
print(drop_10_toggle_player)
# Out:
# False

# %%
## testing player

if player_hand_total == 21:
    print(f'Blackjack!')
        
##user input
# '1' and '0' are strings
user_data = '1'
drop_10_toggle_player = False

while user_data != '0':
    
    print(f"You have {player_hand} for a total of {player_hand_total}. Dealer is showing {dealer_hand[0]} for a total of {rank_value_dict[dealer_hand[0].split()[0]]}. Press '1' to HIT, Press '0' to STAND")
    user_data = input()
    
    if user_data == '1':

        print(f'Player HITS')
        #draw card function, embed in deal hand function inside 'hit'
        #ensure player_hand_total also updates
        #ensure total cards left updates
        new_card = live_deck_tester_copy.pop()
        
        player_hand.append(new_card)
        
        rank,suit = new_card.split()
        
        player_hand_total = player_hand_total + rank_value_dict[rank]
        
        if rank == 'Ace':
            AcePlay_Player = True
    
        if player_hand_total > 21:
            if AcePlay_Player == True:
                if drop_10_toggle_player == False: #include single-use drop10 trigger
                    player_hand_total = player_hand_total - 10
                    drop_10_toggle_player = True
                
                else:
                    print(f'Player BUSTS')
            else:
                print(f'Player goes BOOM')
        ###
    elif user_data == '0':
        print(f'Player STANDS')
        ###
    else:
        print(f"INCORRECT ENTRY")
# Out:
# You have ['Seven Diamonds', 'Ace Spades'] for a total of 18. Dealer is showing Five Spades for a total of 5. Press '1' to HIT, Press '0' to STAND
#  1
# Player HITS
# You have ['Seven Diamonds', 'Ace Spades', 'Five Hearts'] for a total of 13. Dealer is showing Five Spades for a total of 5. Press '1' to HIT, Press '0' to STAND
#  1
# Player HITS
# Player BUSTS
# You have ['Seven Diamonds', 'Ace Spades', 'Five Hearts', 'Queen Clubs'] for a total of 23. Dealer is showing Five Spades for a total of 5. Press '1' to HIT, Press '0' to STAND

# %%
print(f'dealer hand:{dealer_hand}')
print(f'dealer hand total: {dealer_hand_total}')
print(live_deck_tester_copy)
len(live_deck_tester_copy)
print(player_hand)
# Out:
# dealer hand:['King Diamonds', 'Nine Hearts']
# dealer hand total: 19
# ['Six Hearts', 'Ace Clubs', 'Three Spades', 'Four Clubs', 'Six Clubs', 'Two Diamonds', 'Seven Clubs', 'King Hearts', 'Queen Spades', 'Seven Diamonds', 'Five Clubs', 'Ace Spades', 'Eight Clubs', 'Ace Hearts', 'Nine Spades', 'Four Hearts', 'Five Spades', 'Ace Diamonds', 'Queen Hearts', 'Ten Clubs', 'Three Hearts', 'Six Spades', 'Five Hearts', 'Three Diamonds', 'King Clubs', 'Three Clubs', 'Ten Diamonds', 'Five Diamonds', 'Two Hearts', 'Two Clubs', 'Eight Diamonds', 'Jack Diamonds', 'Nine Clubs', 'Jack Spades', 'Seven Hearts', 'Six Diamonds', 'Eight Spades', 'Four Spades', 'Queen Diamonds', 'Seven Spades', 'Eight Hearts', 'Ten Spades', 'Queen Clubs', 'Nine Diamonds', 'King Spades', 'Two Spades', 'Jack Hearts', 'Jack Clubs']
# ['Four Diamonds', 'Ten Hearts']

# %%
##testing dealer

#drop_10_toggle_dealer = False 

if dealer_hand_total == 21:
    print(f'Blackjack!')
    
#greater 17
if dealer_hand_total > 17:
    print(f'Dealer Stands')
        
#equal 17
if dealer_hand_total == 17: #note, hit on soft 17'
    print(f'equaller')
    if AcePlay_Dealer == False:
    
        print(f'Dealer Stands')
    
    else:
        
        player_hand_total = player_hand_total - 10
        
        drop_10_player = True
        
        new_card = dealer_hand.append(live_deck_tester_copy.pop())
    
        dealer_hand.append(new_card)

        rank,suit = new_card.split()
    
        dealer_hand_total = dealer_hand_total + rank_value_dict[rank]

#less 17
if dealer_hand_total < 17:

    new_card = live_deck_tester_copy.pop()
    
    dealer_hand.append(new_card)

    rank,suit = new_card.split()     
    
    dealer_hand_total = dealer_hand_total + rank_value_dict[rank]
    
    if rank == 'Ace':
        AcePlay_Dealer = True
    print(f'dealers hand is now: {dealer_hand}')
#     if dealer_hand_total == 17 and AcePlay_Dealer == True: ## **and toggle == false: 
#         #subtract 10
#         #include drop_10 dealer toggle (note, unique toggle for dealer and player)
    
# # if dealer_hand_total > 21:
# #     if AcePlayer == False:
# #         print(f'Dealer BUSTS')
# Out:
# dealers hand is now: ['Two Hearts', 'Six Spades', 'Jack Diamonds']

# %%
player_hand.append(live_deck_copy.pop())

for card in player_hand:
    rank,suit = card.split()
    player_hand_total = player_hand_total + rank_value_dict[rank]

print(f"Player's Current Hand: {player_hand}. Hand Total: {player_hand_total}")
print(f"Dealer's Hand: {dealer_hand}. Hand Total: {dealer_hand_total}")
print(f"Number of Cards Remaining in Deck: {len(live_deck_copy)}")

# %%
dealer_hand.append(live_deck_copy.pop())

for card in dealer_hand:
    rank,suit = card.split()
    dealer_hand_total = dealer_hand_total + rank_value_dict[rank]

# %%
print(f"Player's Current Hand: {player_hand}. Hand Total: {player_hand_total}")
print(f"Dealer's Hand: {dealer_hand}. Hand Total: {dealer_hand_total}")
print(f"Number of Cards Remaining in Deck: {len(live_deck_copy)}")

# %%
player_hand.append(live_deck_copy.pop())

for card in player_hand:
    rank,suit = card.split()
    player_hand_total = player_hand_total + rank_value_dict[rank]
    
print(f"Player's Current Hand: {player_hand}. Hand Total: {player_hand_total}")
print(f"Dealer's Hand: {dealer_hand}. Hand Total: {dealer_hand_total}")
print(f"Number of Cards Remaining in Deck: {len(live_deck_copy)}")

# %%
dealer_hand.append(live_deck_copy.pop())

for card in dealer_hand:
    rank,suit = card.split()
    dealer_hand_total = dealer_hand_total + rank_value_dict[rank]
    
print(f"Player's Current Hand: {player_hand}. Hand Total: {player_hand_total}")
print(f"Dealer's Hand: {dealer_hand}. Hand Total: {dealer_hand_total}")
print(f"Number of Cards Remaining in Deck: {len(live_deck_copy)}")

# %% [markdown]
# # Eight-Deck (for later)

# %%
eight_deck = []
for card in single_deck:
    for i in range(0,8):
        eight_deck.append(card)

# %%
#conditional below, on user input
## '1' and '0' are strings
user_data = '1'

while user_data != '0':
    print(f"You have {player_hand} for a total of {player_hand_total}. The dealer is showing {dealer_hand[1]}. Press '1' to HIT, Press '0' to STAND")
    user_data = input()
    
    if user_data == '1':
        #draw card function, embed in deal hand function inside 'hit'
        #ensure player_hand_total also updates
        #ensure total cards left updates
        #
        print(f'Player HITs')
        ###
    elif user_data == '0':
        print(f'Player STANDS')
        ###
    else:
        print(f"INCORRECT ENTRY")

# %%
len(live_deck_copy)

# %% [markdown]
# #functions:
# function for deal-hand and embed that into a function for dealing a round. embed that into a function for a game 'do you still want to play'
#
# draw card function, embed in deal hand function inside 'hit'
#
# implement 'Ace Check' first before 'bust check', will be contingent on both dealer and player. << which, if ace is present and player
# busts', will be interpretted as a '1' instead of '11', proceed accordingly.
# ^^ dealer rule for ACE, soft vs. hard 17, proceed accordingly.
#
# 'bust check' player first, dealer wouldnt have to go. then bust check player, end hand etc.

# %% [markdown]
# # Play-Hand Function ('function to be made')

# %%
def hand_total_calculator(hand):
    

def bust_checker(hand):
    hand_total = 0
    max_total = 21
    for card in hand:
        rank,suit = card.split()
        if rank == 'Ace':
            max_total = 31
        hand_total = hand_total + rank_value_dict[rank]
    if hand_total > max_total:
        #

# %%
def bust_checker(hand):
    max_total = 21
    for card in hand:
        rank,suit = card.split()
        if rank == 'Ace':
            max_total = 31
